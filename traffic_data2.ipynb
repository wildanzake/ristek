# %%
import os
import requests
import pandas as pd
import schedule
import time

# %%
points = {
    "gedebage_bandung" : "-6.937116,107.692572",
    "samsat_soekarno_hatta" : "-6.945551,107.641822",
    "buah_batu" : "-6.947964,107.633368",
    "batununggal" : "-6.949535,107.626021",
    "cigereleng" : "-6.948386,107.609370",
    "cibaduyut" : "-6.947362,107.595209",
    "kopo" : "-6.945652,107.589641",
    "caringin" : "-6.943117,107.584381",
    "pasir_koja" : "-6.930483,107.575955",
    "cibeureum" : "-6.917362,107.574349",
}

for key in points:
    df = pd.DataFrame(columns=["frc","currentSpeed","freeFlowSpeed","currentTravelTime",
                               "freeFlowTravelTime","confidence","roadClosure","coordinates",
                               "@version","date"])
    df.to_csv(f"traffic_data/traffic_data_{key}.csv", index=False)

# %%
# Ganti dengan API key Anda
api_key = "JQweTAxNLo7NbEAyABC2gX0yemPehTGM"

# Endpoint untuk mengambil data lalu lintas
endpoint = "https://api.tomtom.com/traffic/services/4/flowSegmentData/absolute/10/json"

def fetch_and_store_traffic_data(point_key,latlong):
    parameters = {
        "point": latlong,
        "unit": "KMPH",
        "key": api_key
    }

    response = requests.get(endpoint, params=parameters)
    data = response.json()

    # Mengubah data menjadi DataFrame
    traffic = pd.read_csv(f"traffic_data/traffic_data_{point_key}.csv")
    d = pd.DataFrame(data['flowSegmentData'])
    date = response.headers['date']
    d['date'] = date

    # Concatenate the new data with the existing traffic DataFrame
    df = pd.concat([traffic, d], ignore_index=True)

    # Menyimpan DataFrame dalam file CSV
    csv_filename = f"traffic_data/traffic_data_{point_key}.csv"
    df.to_csv(csv_filename, index=False)
    print(f"Data lalu lintas di Jakarta disimpan dalam {csv_filename}")

# Schedule the function to run every 1 minutes
# schedule.every(1).minutes.do(fetch_and_store_traffic_data)

while True:
    for key in points:
        fetch_and_store_traffic_data(key,points[key])
    # schedule.run_pending()
    time.sleep(1)
# Out:
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cigereleng.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibaduyut.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_kopo.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_caringin.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_pasir_koja.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_cibeureum.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_gedebage_bandung.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_samsat_soekarno_hatta.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_buah_batu.csv
# Data lalu lintas di Jakarta disimpan dalam traffic_data/traffic_data_batununggal.csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16188\3770800252.py in <module>
#      34 while True:
#      35     for key in points:
# ---> 36         fetch_and_store_traffic_data(key,points[key])
#      37     # schedule.run_pending()
#      38     time.sleep(1)
#
# ~\AppData\Local\Temp\ipykernel_16188\3770800252.py in fetch_and_store_traffic_data(point_key, latlong)
#      12     }
#      13
# ---> 14     response = requests.get(endpoint, params=parameters)
#      15     data = response.json()
#      16
#
# c:\Users\vnang\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# c:\Users\vnang\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# c:\Users\vnang\anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# c:\Users\vnang\anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# c:\Users\vnang\anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# c:\Users\vnang\anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# c:\Users\vnang\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\Users\vnang\anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\Users\vnang\anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# c:\Users\vnang\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# c:\Users\vnang\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# c:\Users\vnang\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# c:\Users\vnang\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# c:\Users\vnang\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# c:\Users\vnang\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
